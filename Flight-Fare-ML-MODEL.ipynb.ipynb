# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # import dataset

# %%
data=pd.read_excel(r"D:\python\ml\live-ml-project\ML Live Flight Fare Resourses16963295320.xlsx")
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %% [markdown]
# # show the first five rows

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# # Chech basic information of dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# # to show all column name

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# # to delete columns use drop

# %%
data.drop(["Route","Additional_Info"],axis=1,inplace=True)

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi    22:20
# 1        Air India       1/05/2019   Kolkata    Banglore    05:50
# 2      Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 3           IndiGo      12/05/2019   Kolkata    Banglore    18:05
# 4           IndiGo      01/03/2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore    19:55
# 10679    Air India      27/04/2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27/04/2019  Banglore       Delhi    08:20
# 10681      Vistara      01/03/2019  Banglore   New Delhi    11:30
# 10682    Air India       9/05/2019     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops  Price
# 0      01:10 22 Mar   2h 50m    non-stop   3897
# 1             13:15   7h 25m     2 stops   7662
# ...

# %% [markdown]
# # check the count of null values in dataset column

# %%
data.isnull().any()
# Out:
# Airline            False
# Date_of_Journey    False
# Source             False
# Destination        False
# Dep_Time           False
# Arrival_Time       False
# Duration           False
# Total_Stops         True
# Price              False
# dtype: bool

# %% [markdown]
# # check the count how many of null values in dataset column

# %%
data["Total_Stops"].isnull().sum()
# Out:
# 1

# %% [markdown]
# # check the particular null row data values in dataset column

# %%
data[data["Total_Stops"].isnull()==True]
# Out:
#         Airline Date_of_Journey Source Destination Dep_Time  Arrival_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin    09:45  09:25 07 May
#
#      Duration Total_Stops  Price
# 9039  23h 40m         NaN   7480

# %% [markdown]
# # to drop column permantly use inplace

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi    22:20
# 1        Air India       1/05/2019   Kolkata    Banglore    05:50
# 2      Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 3           IndiGo      12/05/2019   Kolkata    Banglore    18:05
# 4           IndiGo      01/03/2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore    19:55
# 10679    Air India      27/04/2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27/04/2019  Banglore       Delhi    08:20
# 10681      Vistara      01/03/2019  Banglore   New Delhi    11:30
# 10682    Air India       9/05/2019     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops  Price
# 0      01:10 22 Mar   2h 50m    non-stop   3897
# 1             13:15   7h 25m     2 stops   7662
# ...

# %% [markdown]
# # Date

# %%
data["Date_of_Journey"]
# Out:
# 0        24/03/2019
# 1         1/05/2019
# 2         9/06/2019
# 3        12/05/2019
# 4        01/03/2019
#             ...
# 10678     9/04/2019
# 10679    27/04/2019
# 10680    27/04/2019
# 10681    01/03/2019
# 10682     9/05/2019
# Name: Date_of_Journey, Length: 10682, dtype: object

# %% [markdown]
# # set proper datetime

# %%
pd.to_datetime(data["Date_of_Journey"])
# Out:
# 0       2019-03-24
# 1       2019-05-01
# 2       2019-06-09
# 3       2019-05-12
# 4       2019-03-01
#            ...
# 10678   2019-04-09
# 10679   2019-04-27
# 10680   2019-04-27
# 10681   2019-03-01
# 10682   2019-05-09
# Name: Date_of_Journey, Length: 10682, dtype: datetime64[ns]

# %% [markdown]
# # Now we extract  day values and month values from Date_of_Journey and create two new columns Journey_month & Journey_date

# %%
data["journey_month"]=pd.to_datetime(data["Date_of_Journey"]).dt.month
data["journey_month"]
# Out:
# 0        3
# 1        5
# 2        6
# 3        5
# 4        3
#         ..
# 10678    4
# 10679    4
# 10680    4
# 10681    3
# 10682    5
# Name: journey_month, Length: 10682, dtype: int32

# %%
data["journey_date"]=pd.to_datetime(data["Date_of_Journey"]).dt.day
data["journey_date"]
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4         1
#          ..
# 10678     9
# 10679    27
# 10680    27
# 10681     1
# 10682     9
# Name: journey_date, Length: 10682, dtype: int32

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi    22:20
# 1        Air India       1/05/2019   Kolkata    Banglore    05:50
# 2      Jet Airways       9/06/2019     Delhi      Cochin    09:25
# 3           IndiGo      12/05/2019   Kolkata    Banglore    18:05
# 4           IndiGo      01/03/2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore    19:55
# 10679    Air India      27/04/2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27/04/2019  Banglore       Delhi    08:20
# 10681      Vistara      01/03/2019  Banglore   New Delhi    11:30
# 10682    Air India       9/05/2019     Delhi      Cochin    10:55
#
#        Arrival_Time Duration Total_Stops  Price  journey_month  journey_date
# 0      01:10 22 Mar   2h 50m    non-stop   3897              3            24
# ...

# %%
# after extract date and month not need of date of journey column so we drop is

# %%
data.drop("Date_of_Journey",axis=1,inplace=True)

# %%
data
# Out:
#            Airline    Source Destination Dep_Time  Arrival_Time Duration  \
# 0           IndiGo  Banglore   New Delhi    22:20  01:10 22 Mar   2h 50m
# 1        Air India   Kolkata    Banglore    05:50         13:15   7h 25m
# 2      Jet Airways     Delhi      Cochin    09:25  04:25 10 Jun      19h
# 3           IndiGo   Kolkata    Banglore    18:05         23:30   5h 25m
# 4           IndiGo  Banglore   New Delhi    16:50         21:35   4h 45m
# ...            ...       ...         ...      ...           ...      ...
# 10678     Air Asia   Kolkata    Banglore    19:55         22:25   2h 30m
# 10679    Air India   Kolkata    Banglore    20:45         23:20   2h 35m
# 10680  Jet Airways  Banglore       Delhi    08:20         11:20       3h
# 10681      Vistara  Banglore   New Delhi    11:30         14:10   2h 40m
# 10682    Air India     Delhi      Cochin    10:55         19:15   8h 20m
#
#       Total_Stops  Price  journey_month  journey_date
# ...

# %% [markdown]
# # to extract hours and minutes od dep_time and create new columns for date

# %%
data["dep_hours"]=pd.to_datetime(data["Dep_Time"]).dt.hour
data["dep_hours"]
# Out:
# 0        22
# 1         5
# 2         9
# 3        18
# 4        16
#          ..
# 10678    19
# 10679    20
# 10680     8
# 10681    11
# 10682    10
# Name: dep_hours, Length: 10682, dtype: int32

# %%
data["dep_minutes"]=pd.to_datetime(data["Dep_Time"]).dt.minute
data["dep_minutes"]
# Out:
# 0        20
# 1        50
# 2        25
# 3         5
# 4        50
#          ..
# 10678    55
# 10679    45
# 10680    20
# 10681    30
# 10682    55
# Name: dep_minutes, Length: 10682, dtype: int32

# %%
data
# Out:
#            Airline    Source Destination Dep_Time  Arrival_Time Duration  \
# 0           IndiGo  Banglore   New Delhi    22:20  01:10 22 Mar   2h 50m
# 1        Air India   Kolkata    Banglore    05:50         13:15   7h 25m
# 2      Jet Airways     Delhi      Cochin    09:25  04:25 10 Jun      19h
# 3           IndiGo   Kolkata    Banglore    18:05         23:30   5h 25m
# 4           IndiGo  Banglore   New Delhi    16:50         21:35   4h 45m
# ...            ...       ...         ...      ...           ...      ...
# 10678     Air Asia   Kolkata    Banglore    19:55         22:25   2h 30m
# 10679    Air India   Kolkata    Banglore    20:45         23:20   2h 35m
# 10680  Jet Airways  Banglore       Delhi    08:20         11:20       3h
# 10681      Vistara  Banglore   New Delhi    11:30         14:10   2h 40m
# 10682    Air India     Delhi      Cochin    10:55         19:15   8h 20m
#
#       Total_Stops  Price  journey_month  journey_date  dep_hours  dep_minutes
# ...

# %%
# after extract hour and min not need of dep_time column so we drop is

# %%
data.drop("Dep_Time",axis=1,inplace=True)

# %%
data
# Out:
#            Airline    Source Destination  Arrival_Time Duration Total_Stops  \
# 0           IndiGo  Banglore   New Delhi  01:10 22 Mar   2h 50m    non-stop
# 1        Air India   Kolkata    Banglore         13:15   7h 25m     2 stops
# 2      Jet Airways     Delhi      Cochin  04:25 10 Jun      19h     2 stops
# 3           IndiGo   Kolkata    Banglore         23:30   5h 25m      1 stop
# 4           IndiGo  Banglore   New Delhi         21:35   4h 45m      1 stop
# ...            ...       ...         ...           ...      ...         ...
# 10678     Air Asia   Kolkata    Banglore         22:25   2h 30m    non-stop
# 10679    Air India   Kolkata    Banglore         23:20   2h 35m    non-stop
# 10680  Jet Airways  Banglore       Delhi         11:20       3h    non-stop
# 10681      Vistara  Banglore   New Delhi         14:10   2h 40m    non-stop
# 10682    Air India     Delhi      Cochin         19:15   8h 20m     2 stops
#
# ...

# %% [markdown]
# # to extract hours and minutes od arr_time and create new columns for date

# %%
data["Arrival_hour"] = pd.to_datetime(data.Arrival_Time).dt.hour
data["Arrival_hour"]
# Out:
# 0         1
# 1        13
# 2         4
# 3        23
# 4        21
#          ..
# 10678    22
# 10679    23
# 10680    11
# 10681    14
# 10682    19
# Name: Arrival_hour, Length: 10682, dtype: int32

# %%
data["Arrival_min"] = pd.to_datetime(data.Arrival_Time).dt.minute
data["Arrival_min"]
# Out:
# 0        10
# 1        15
# 2        25
# 3        30
# 4        35
#          ..
# 10678    25
# 10679    20
# 10680    20
# 10681    10
# 10682    15
# Name: Arrival_min, Length: 10682, dtype: int32

# %%
# after extract hour and min not need of arr_time column so we drop is

# %%
data.drop(["Arrival_Time"], axis = 1, inplace = True)

# %%
data
# Out:
#            Airline    Source Destination Duration Total_Stops  Price  \
# 0           IndiGo  Banglore   New Delhi   2h 50m    non-stop   3897
# 1        Air India   Kolkata    Banglore   7h 25m     2 stops   7662
# 2      Jet Airways     Delhi      Cochin      19h     2 stops  13882
# 3           IndiGo   Kolkata    Banglore   5h 25m      1 stop   6218
# 4           IndiGo  Banglore   New Delhi   4h 45m      1 stop  13302
# ...            ...       ...         ...      ...         ...    ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m    non-stop   4107
# 10679    Air India   Kolkata    Banglore   2h 35m    non-stop   4145
# 10680  Jet Airways  Banglore       Delhi       3h    non-stop   7229
# 10681      Vistara  Banglore   New Delhi   2h 40m    non-stop  12648
# 10682    Air India     Delhi      Cochin   8h 20m     2 stops  11753
#
#        journey_month  journey_date  dep_hours  dep_minutes  Arrival_hour  \
# ...

# %% [markdown]
# # ml-enlabel

# %% [markdown]
# # column Airline

# %%
data.groupby("Airline")["Price"].mean()
# Out:
# Airline
# Air Asia                              5590.260188
# Air India                             9612.427756
# GoAir                                 5861.056701
# IndiGo                                5673.682903
# Jet Airways                          11643.923357
# Jet Airways Business                 58358.666667
# Multiple carriers                    10902.678094
# Multiple carriers Premium economy    11418.846154
# SpiceJet                              4338.284841
# Trujet                                4140.000000
# Vistara                               7796.348643
# Vistara Premium economy               8962.333333
# Name: Price, dtype: float64

# %%
# create plot

# %%
data.groupby("Airline")["Price"].mean().plot()
# Out:
# <Axes: xlabel='Airline'>

# %% [markdown]
# # one hot encoding for Airline

# %%
Airline=pd.get_dummies(data["Airline"])
Airline
# Out:
#        Air Asia  Air India  GoAir  IndiGo  Jet Airways  Jet Airways Business  \
# 0         False      False  False    True        False                 False
# 1         False       True  False   False        False                 False
# 2         False      False  False   False         True                 False
# 3         False      False  False    True        False                 False
# 4         False      False  False    True        False                 False
# ...         ...        ...    ...     ...          ...                   ...
# 10678      True      False  False   False        False                 False
# 10679     False       True  False   False        False                 False
# 10680     False      False  False   False         True                 False
# 10681     False      False  False   False        False                 False
# 10682     False       True  False   False        False                 False
#
# ...

# %%
#Airline.columns

# %% [markdown]
# # column Source

# %%
data.groupby("Source")["Price"].mean().plot()
# Out:
# <Axes: xlabel='Source'>

# %%
Source=pd.get_dummies(data["Source"])
Source
# Out:
#        Banglore  Chennai  Delhi  Kolkata  Mumbai
# 0          True    False  False    False   False
# 1         False    False  False     True   False
# 2         False    False   True    False   False
# 3         False    False  False     True   False
# 4          True    False  False    False   False
# ...         ...      ...    ...      ...     ...
# 10678     False    False  False     True   False
# 10679     False    False  False     True   False
# 10680      True    False  False    False   False
# 10681      True    False  False    False   False
# 10682     False    False   True    False   False
#
# [10682 rows x 5 columns]

# %% [markdown]
# # column Destination

# %%
data.groupby("Destination")["Price"].mean().plot()
# Out:
# <Axes: xlabel='Destination'>

# %%
Destination=pd.get_dummies(data["Destination"])
Destination
# Out:
#        Banglore  Cochin  Delhi  Hyderabad  Kolkata  New Delhi
# 0         False   False  False      False    False       True
# 1          True   False  False      False    False      False
# 2         False    True  False      False    False      False
# 3          True   False  False      False    False      False
# 4         False   False  False      False    False       True
# ...         ...     ...    ...        ...      ...        ...
# 10678      True   False  False      False    False      False
# 10679      True   False  False      False    False      False
# 10680     False   False   True      False    False      False
# 10681     False   False  False      False    False       True
# 10682     False    True  False      False    False      False
#
# [10682 rows x 6 columns]

# %% [markdown]
# # Column Total_Stops

# %%
data["Total_Stops"].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %% [markdown]
# # ordinal encoding for Total_Stops

# %%
data["Total_Stops"].replace(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],[0,2,1,3,4],inplace=True)

# %%
data
# Out:
#            Airline    Source Destination Duration  Total_Stops  Price  \
# 0           IndiGo  Banglore   New Delhi   2h 50m            0   3897
# 1        Air India   Kolkata    Banglore   7h 25m            2   7662
# 2      Jet Airways     Delhi      Cochin      19h            2  13882
# 3           IndiGo   Kolkata    Banglore   5h 25m            1   6218
# 4           IndiGo  Banglore   New Delhi   4h 45m            1  13302
# ...            ...       ...         ...      ...          ...    ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m            0   4107
# 10679    Air India   Kolkata    Banglore   2h 35m            0   4145
# 10680  Jet Airways  Banglore       Delhi       3h            0   7229
# 10681      Vistara  Banglore   New Delhi   2h 40m            0  12648
# 10682    Air India     Delhi      Cochin   8h 20m            2  11753
#
#        journey_month  journey_date  dep_hours  dep_minutes  Arrival_hour  \
# ...

# %%
#Airline
#Source
#Destination

# %%
data=pd.concat([data,Airline,Source,Destination],axis=1)

# %%
data
# Out:
#            Airline    Source Destination Duration  Total_Stops  Price  \
# 0           IndiGo  Banglore   New Delhi   2h 50m            0   3897
# 1        Air India   Kolkata    Banglore   7h 25m            2   7662
# 2      Jet Airways     Delhi      Cochin      19h            2  13882
# 3           IndiGo   Kolkata    Banglore   5h 25m            1   6218
# 4           IndiGo  Banglore   New Delhi   4h 45m            1  13302
# ...            ...       ...         ...      ...          ...    ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m            0   4107
# 10679    Air India   Kolkata    Banglore   2h 35m            0   4145
# 10680  Jet Airways  Banglore       Delhi       3h            0   7229
# 10681      Vistara  Banglore   New Delhi   2h 40m            0  12648
# 10682    Air India     Delhi      Cochin   8h 20m            2  11753
#
#        journey_month  journey_date  dep_hours  dep_minutes  ...  Chennai  \
# ...

# %% [markdown]
# # to show all the columns

# %%
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops  Price  \
# 0       IndiGo  Banglore   New Delhi   2h 50m            0   3897
# 1    Air India   Kolkata    Banglore   7h 25m            2   7662
# 2  Jet Airways     Delhi      Cochin      19h            2  13882
# 3       IndiGo   Kolkata    Banglore   5h 25m            1   6218
# 4       IndiGo  Banglore   New Delhi   4h 45m            1  13302
#
#    journey_month  journey_date  dep_hours  dep_minutes  Arrival_hour  \
# 0              3            24         22           20             1
# 1              5             1          5           50            13
# 2              6             9          9           25             4
# 3              5            12         18            5            23
# 4              3             1         16           50            21
#
#    Arrival_min  Air Asia  Air India  GoAir  IndiGo  Jet Airways  \
# 0           10     False      False  False    True        False
# ...

# %% [markdown]
# # to make a copy of original data

# %%
df=data.copy()

# %% [markdown]
# # column Duration

# %%
df["Duration"]
# Out:
# 0        2h 50m
# 1        7h 25m
# 2           19h
# 3        5h 25m
# 4        4h 45m
#           ...
# 10678    2h 30m
# 10679    2h 35m
# 10680        3h
# 10681    2h 40m
# 10682    8h 20m
# Name: Duration, Length: 10682, dtype: object

# %% [markdown]
# # split using indexing here 0 is hour and 1 is minute

# %% [markdown]
# # hours splits[0 index]

# %%
df["Duration_hr"]=df["Duration"].str.split().str[0]

# %%
df
# Out:
#            Airline    Source Destination Duration  Total_Stops  Price  \
# 0           IndiGo  Banglore   New Delhi   2h 50m            0   3897
# 1        Air India   Kolkata    Banglore   7h 25m            2   7662
# 2      Jet Airways     Delhi      Cochin      19h            2  13882
# 3           IndiGo   Kolkata    Banglore   5h 25m            1   6218
# 4           IndiGo  Banglore   New Delhi   4h 45m            1  13302
# ...            ...       ...         ...      ...          ...    ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m            0   4107
# 10679    Air India   Kolkata    Banglore   2h 35m            0   4145
# 10680  Jet Airways  Banglore       Delhi       3h            0   7229
# 10681      Vistara  Banglore   New Delhi   2h 40m            0  12648
# 10682    Air India     Delhi      Cochin   8h 20m            2  11753
#
#        journey_month  journey_date  dep_hours  dep_minutes  Arrival_hour  \
# ...

# %% [markdown]
# # minute split[1 index]

# %%
df["Duration_min"]=df["Duration"].str.split().str[1]

# %%
df
# Out:
#            Airline    Source Destination Duration  Total_Stops  Price  \
# 0           IndiGo  Banglore   New Delhi   2h 50m            0   3897
# 1        Air India   Kolkata    Banglore   7h 25m            2   7662
# 2      Jet Airways     Delhi      Cochin      19h            2  13882
# 3           IndiGo   Kolkata    Banglore   5h 25m            1   6218
# 4           IndiGo  Banglore   New Delhi   4h 45m            1  13302
# ...            ...       ...         ...      ...          ...    ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m            0   4107
# 10679    Air India   Kolkata    Banglore   2h 35m            0   4145
# 10680  Jet Airways  Banglore       Delhi       3h            0   7229
# 10681      Vistara  Banglore   New Delhi   2h 40m            0  12648
# 10682    Air India     Delhi      Cochin   8h 20m            2  11753
#
#        journey_month  journey_date  dep_hours  dep_minutes  Arrival_hour  \
# ...

# %% [markdown]
# # fillna for all null values

# %%
df["Duration_hr"].fillna(0,inplace=True)

# %%
df["Duration_min"].fillna(0,inplace=True)

# %% [markdown]
# # replace h and m from the duration column data

# %%
df[["Duration_hr","Duration_min"]]=df[["Duration_hr","Duration_min"]].replace("[h-m]"," ",regex=True) # use regex for regular expression

# %%
df
# Out:
#            Airline    Source Destination Duration  Total_Stops  Price  \
# 0           IndiGo  Banglore   New Delhi   2h 50m            0   3897
# 1        Air India   Kolkata    Banglore   7h 25m            2   7662
# 2      Jet Airways     Delhi      Cochin      19h            2  13882
# 3           IndiGo   Kolkata    Banglore   5h 25m            1   6218
# 4           IndiGo  Banglore   New Delhi   4h 45m            1  13302
# ...            ...       ...         ...      ...          ...    ...
# 10678     Air Asia   Kolkata    Banglore   2h 30m            0   4107
# 10679    Air India   Kolkata    Banglore   2h 35m            0   4145
# 10680  Jet Airways  Banglore       Delhi       3h            0   7229
# 10681      Vistara  Banglore   New Delhi   2h 40m            0  12648
# 10682    Air India     Delhi      Cochin   8h 20m            2  11753
#
#        journey_month  journey_date  dep_hours  dep_minutes  Arrival_hour  \
# ...

# %% [markdown]
# # change datatype str to int

# %%
df[["Duration_hr","Duration_min"]]=df[["Duration_hr","Duration_min"]].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Airline                            10682 non-null  object
#  1   Source                             10682 non-null  object
#  2   Destination                        10682 non-null  object
#  3   Duration                           10682 non-null  object
#  4   Total_Stops                        10682 non-null  int64
#  5   Price                              10682 non-null  int64
#  6   journey_month                      10682 non-null  int32
#  7   journey_date                       10682 non-null  int32
#  8   dep_hours                          10682 non-null  int32
#  9   dep_minutes                        10682 non-null  int32
#  10  Arrival_hour                       10682 non-null  int32
# ...

# %% [markdown]
# # now store df into data

# %%
data=df.copy()

# %% [markdown]
# # drop all non needed column

# %%
data.drop(["Airline","Source","Destination","Duration"],axis=1,inplace=True)

# %% [markdown]
# # arrange all columns in sequence

# %%
data.columns
# Out:
# Index(['Total_Stops', 'Price', 'journey_month', 'journey_date', 'dep_hours',
#        'dep_minutes', 'Arrival_hour', 'Arrival_min', 'Air Asia', 'Air India',
#        'GoAir', 'IndiGo', 'Jet Airways', 'Jet Airways Business',
#        'Multiple carriers', 'Multiple carriers Premium economy', 'SpiceJet',
#        'Trujet', 'Vistara', 'Vistara Premium economy', 'Banglore', 'Chennai',
#        'Delhi', 'Kolkata', 'Mumbai', 'Banglore', 'Cochin', 'Delhi',
#        'Hyderabad', 'Kolkata', 'New Delhi', 'Duration_hr', 'Duration_min'],
#       dtype='object')

# %%
data=data[['Total_Stops', 'journey_month', 'journey_date', 'dep_hours',
       'dep_minutes', 'Arrival_hour', 'Arrival_min', 'Duration_hr', 'Duration_min', 'Air Asia', 'Air India',
       'GoAir', 'IndiGo', 'Jet Airways', 'Jet Airways Business',
       'Multiple carriers', 'Multiple carriers Premium economy', 'SpiceJet',
       'Trujet', 'Vistara', 'Vistara Premium economy', 'Banglore', 'Chennai',
       'Delhi', 'Kolkata', 'Mumbai', 'Banglore', 'Cochin', 'Delhi',
       'Hyderabad', 'Kolkata', 'New Delhi', 'Price']]

# %%
data
# Out:
#        Total_Stops  journey_month  journey_date  dep_hours  dep_minutes  \
# 0                0              3            24         22           20
# 1                2              5             1          5           50
# 2                2              6             9          9           25
# 3                1              5            12         18            5
# 4                1              3             1         16           50
# ...            ...            ...           ...        ...          ...
# 10678            0              4             9         19           55
# 10679            0              4            27         20           45
# 10680            0              4            27          8           20
# 10681            0              3             1         11           30
# 10682            2              5             9         10           55
#
#        Arrival_hour  Arrival_min  Duration_hr  Duration_min  Air Asia  \
# ...

# %%
data.to_excel("filter data of airport.xlsx")

# %%
pwd
# Out:
# 'C:\\Users\\HP\\fingertips\\ML\\ml-projects'
